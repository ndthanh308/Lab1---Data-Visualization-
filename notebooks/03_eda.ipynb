# %% [markdown]
# # Cài đặt thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %% [markdown]
# # EDA cơ bản

# %%
current_path = os.getcwd()
parrent_path = os.path.dirname(current_path)

NAME_DATASET = "9_final_clean.csv"
data_path = os.path.join(parrent_path, "data", "processed", NAME_DATASET)

# %%
df = pd.read_csv(data_path, encoding="utf-8")
df.head(5)
# Out:
#            ID   price   area        ppm2  price_increased  \
# 0  18002827.0   2.700   56.0   48.214286             17.9
# 1  44881455.0  15.160  289.0   52.456747              2.1
# 2  24453570.0  13.671  220.5   62.000000             11.3
# 3  37714881.0  15.300  170.1   89.947090             32.2
# 4  44010390.0  29.500  225.0  131.111111             10.4
#
#                                           page_title  has_pink_book  \
# 0  Căn hộ sổ hồng 2PN - 2,7 tỷ thương mại Imperia...              1
# 1  Bán đất mặt tiền đường Bình Trưng, 289m², cách...              1
# 2  Cần bán các lô đất KDC Xuất Nhập Khẩu Tổng Hợp...              1
# 3  Giảm giá 1.5ty Bán nhà mt 1030 Lê Văn Lương, 6...              1
# 4  Cần bán căn hộ mini tại địa chỉ 20/24 đường Số...              1
#
#    num_bathrooms  num_bedrooms  num_floors  ...  district         city  \
# 0            1.0           2.0         NaN  ...  Bình Tân  Hồ Chí Minh
# ...

# %% [markdown]
# # 1. Phân tích tổng thể dữ liệu

# %% [markdown]
# ## 1.1. Phân tích đơn biến

# %% [markdown]
# ## 1.2. Phân tích nhiều biến

# %% [markdown]
# ## 1.3. Quan sát và insight

# %% [markdown]
# ### 1.3.1. Summary

# %% [markdown]
# ### 1.3.2. Red flags

# %% [markdown]
# # 2. Đặt câu hỏi phân tích
