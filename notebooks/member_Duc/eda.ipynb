# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import geopandas as gpd

# %%
current = os.getcwd()
parrent = os.path.dirname(current)
parrent = os.path.dirname(parrent)
path = os.path.join(parrent, 'data', 'crawling_data.csv')
# path
df = pd.read_csv(path)
df.head(10)
# Out:
#            ID  Giá (tỷ đồng)  Giá đã tăng 1 năm qua (%)  Diện tích  \
# 0  44487856.0          10.40                        NaN       75.0
# 1  45155008.0          23.50                       13.0      168.0
# 2  45152226.0           3.40                       35.8       69.0
# 3  44830349.0           5.40                       11.8       61.5
# 4  45138610.0          11.00                       12.9      310.0
# 5  45049567.0           5.95                       28.6       94.0
# 6  44562727.0           5.40                       12.7       71.2
# 7  44739781.0           7.50                       18.1       50.0
# 8  45024793.0           9.00                        7.8      123.1
# 9  44706561.0          39.00                       18.5      223.8
#
#    Số phòng tắm  Số phòng ngủ  Số tầng  Có nội thất  Mặt tiền(m)  \
# 0           3.0           5.0      5.0            1         5.00
# 1           NaN           NaN      NaN            0         6.20
# 2           2.0           2.0      NaN            1          NaN
# 3           NaN           NaN      NaN            0         6.23
# 4           NaN           NaN      NaN            0         5.00
# 5           NaN           NaN      NaN            0         5.00
# 6           NaN           NaN      NaN            0         4.05
# 7           4.0           4.0      4.0            0         5.00
# 8           NaN           NaN      NaN            0         4.50
# 9           NaN           NaN      NaN            0          NaN
#
#    Đường vào(m)  ...           Loại Tin                  ngày crawl blocked  \
# 0          50.0  ...  Tin VIP Kim Cương  2026-02-13 13:29:12.737075   False
# 1          30.0  ...  Tin VIP Kim Cương  2026-02-13 13:29:19.279342   False
# 2           NaN  ...  Tin VIP Kim Cương  2026-02-13 13:29:26.484077   False
# 3           NaN  ...         Tin thường  2026-02-13 13:29:30.830482   False
# 4           NaN  ...         Tin thường  2026-02-13 13:29:34.138110   False
# 5           NaN  ...         Tin thường  2026-02-13 13:29:37.877373   False
# 6           NaN  ...         Tin thường  2026-02-13 13:29:41.103472   False
# 7           6.0  ...         Tin thường  2026-02-13 13:29:45.239216   False
# 8          10.0  ...         Tin thường  2026-02-13 13:29:48.642916   False
# 9           8.0  ...         Tin thường  2026-02-13 13:29:52.442834   False
#
#                                           source_url  \
# 0  https://batdongsan.com.vn/ban-nha-biet-thu-lie...
# 1  https://batdongsan.com.vn/ban-nha-mat-pho-duon...
# 2  https://batdongsan.com.vn/ban-can-ho-chung-cu-...
# 3  https://batdongsan.com.vn/ban-dat-duong-duong-...
# 4  https://batdongsan.com.vn/ban-dat-duong-14-1-p...
# 5  https://batdongsan.com.vn/ban-dat-duong-u-ghe-...
# 6  https://batdongsan.com.vn/ban-dat-duong-hoang-...
# 7  https://batdongsan.com.vn/ban-nha-rieng-phuong...
# 8  https://batdongsan.com.vn/ban-dat-duong-so-8-p...
# 9  https://batdongsan.com.vn/ban-dat-duong-10a-ph...
#
#                                              address             legal  \
# 0  Vinhomes Green Paradise, Xã Long Hòa, Huyện Cầ...    Sổ đỏ/ Sổ hồng
# 1  Đường Nguyễn Văn Tăng, Phường Long Thạnh Mỹ, Q...    Sổ đỏ/ Sổ hồng
# 2  Vinhomes Grand Park, Phường Long Thạnh Mỹ, Quậ...  Hợp đồng mua bán
# 3  Đường Dương Văn Cam, Phường Linh Tây, Thủ Đức,...   Sổ đỏ/ Sổ hồng.
# 4   Đường 14, Phường Linh Đông, Thủ Đức, Hồ Chí Minh   Sổ đỏ/ Sổ hồng.
# 5  Đường Ụ Ghe, Phường Tam Phú, Thủ Đức, Hồ Chí Minh   Sổ đỏ/ Sổ hồng.
# 6  Đường Hoàng Diệu 2, Phường Linh Chiểu, Thủ Đức...   Sổ đỏ/ Sổ hồng.
# 7             Phường Linh Đông, Thủ Đức, Hồ Chí Minh   Sổ đỏ/ Sổ hồng.
# 8  Đường Số 8, Phường Linh Trung, Thủ Đức, Hồ Chí...   Sổ đỏ/ Sổ hồng.
# 9    Đường 10A, Phường An Khánh, Quận 2, Hồ Chí Minh    Sổ đỏ/ Sổ hồng
#
#    raw_price  raw_area                                         page_title  \
# 0    10,4 tỷ     75 m²  Giỏ hàng độc quyền nhà phố biệt thự Vinhomes C...
# 1    23,5 tỷ    168 m²  Nhà Bán Gấp Trước Tết-chính chủ 6.2mx27.1m -Ng...
# 2     3,4 tỷ     69 m²  Căn hộ Vinhomes 1PN - 2PN - 3PN - chính sách s...
# 3     5,4 tỷ   61,5 m²  Lô góc 2 mặt tiền ngang 6.23m - không lộ giới ...
# 4      11 tỷ    310 m²  Giá đầu tư 35.5tr/m2 đất MT nhánh Linh Đông-kh...
# 5    5,95 tỷ     94 m²  Chỉ 63.3tr/m2 đất full thổ, ngang 5m - hẻm xe ...
# 6     5,4 tỷ   71,2 m²  Linh Chiểu Hoàng Diệu 2 ngay khu dân cư Hải Sơ...
# 7     7,5 tỷ     50 m²  Ngay Phạm Văn Đồng gần chung cư 4S - nhà đẹp 4...
# 8       9 tỷ  123,1 m²  Giá tốt hàng hiếm - ngay Lê Văn Chí kế Hoàng D...
# 9      39 tỷ  223,8 m²  Đất biệt thự đẹp, đường 8 mét, cách Vành Đai T...
#
#              _source_file
# 0  scraped_results_p2.csv
# 1  scraped_results_p2.csv
# 2  scraped_results_p2.csv
# 3  scraped_results_p2.csv
# 4  scraped_results_p2.csv
# 5  scraped_results_p2.csv
# 6  scraped_results_p2.csv
# 7  scraped_results_p2.csv
# 8  scraped_results_p2.csv
# 9  scraped_results_p2.csv
#
# [10 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Giá (tỷ đồng)', 'Giá đã tăng 1 năm qua (%)', 'Diện tích',
#        'Số phòng tắm', 'Số phòng ngủ', 'Số tầng', 'Có nội thất', 'Mặt tiền(m)',
#        'Đường vào(m)', 'Hướng nhà', 'Đường', 'Phường', 'Quận', 'Thành Phố',
#        'Có sổ hồng', 'Có xác thực', 'Ngày đăng', 'Ngày hết hạn', 'Loại Tin',
#        'ngày crawl', 'blocked', 'source_url', 'address', 'legal', 'raw_price',
#        'raw_area', 'page_title', '_source_file'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                              13
# Giá (tỷ đồng)                  478
# Giá đã tăng 1 năm qua (%)      865
# Diện tích                       13
# Số phòng tắm                 10397
# Số phòng ngủ                  9617
# Số tầng                      13986
# Có nội thất                      0
# Mặt tiền(m)                  13278
# Đường vào(m)                 14553
# Hướng nhà                    22650
# Đường                         1346
# Phường                         414
# Quận                            13
# Thành Phố                       17
# Có sổ hồng                       0
# Có xác thực                      0
# Ngày đăng                       13
# Ngày hết hạn                    13
# Loại Tin                        13
# ngày crawl                       0
# blocked                          0
# source_url                       0
# address                         13
# legal                         2918
# raw_price                       13
# raw_area                        13
# page_title                       0
# _source_file                     0
# dtype: int64

# %% [markdown]
# Pipeline:
# 1. EDA
# 2. Handling missing values
# 3. Data normalization
